# %% [markdown]
# # Data Type Mapping (Supabase → OutSystems)
#
# | Supabase Field | Supabase Type | OutSystems Field | OutSystems Type |
# |---------------|--------------|------------------|-----------------|
# | UserID | int8 | UserId | Integer |
# | UserName | varchar | UserName | Text |
# | UserEmail | varchar | UserEmail | Email |
# | UserPhoneNo | varchar | UserPhoneNo | Phone Number |
# | UserBankAccount | varchar | UserBankAccount | Text |
# | UserQualifications | json | UserQualifications | Text |
# | UserReviews | json | UserReviews | Text |
# | ClientRating | float4 | ClientRating | Decimal |
# | VerificationStatus | varchar | VerificationStatus | Text |
# | FreelancerSkills | json | FreelancerSkills | Text |
# | FreelancerRating | float4 | FreelancerRating | Decimal |
# | FreelancerExperience | json | FreelancerExperience | Text |
# | FreelancerStatus | varchar | FreelancerStatus | Text |
